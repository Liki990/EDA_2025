# %% [markdown]
# **step-1: Import required packages**

# %%
import pandas as pd                     #DataFrame operations
import numpy as np                     #Math operations
import matplotlib.pyplot as plt        #plotting 
import seaborn as sns                  # plotting

# %% [markdown]
# **step-2 : create a dataframe using a list**

# %%
names = ['Ramesh', 'Suresh', 'Mahesh']
age = [20,22,24]
pd.DataFrame(zip(names,age))
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  22
# 2  Mahesh  24

# %% [markdown]
# **pd.DataFrame(data,index,columns)**
# - data=None,
# - index: index or array-like
# - columns: index or array-like array([1,2,3])

# %%
names = ['Ramesh', 'Suresh', 'Mahesh']
age = [20,22,24]
#pd.DataFrame(data,index,columns)
pd.DataFrame(names,age)
# Out:
#          0
# 20  Ramesh
# 22  Suresh
# 24  Mahesh

# %%
names = ['Ramesh', 'Suresh', 'Mahesh']
age = [20,22,24]
#pd.DataFrame(data,index,columns)
pd.DataFrame(zip(names,age))
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  22
# 2  Mahesh  24

# %% [markdown]
# **Step-3: Add the column names**

# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,22,24]
cols=['Names','Age']
#pd.DataFrame(data,index,columns)
pd.DataFrame(zip(names,age),columns=cols)
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Mahesh   24

# %% [markdown]
# **step-4: change the index**

# %%
names=['Ramesh','Suresh','Mahesh']
age=[20,22,24]
cols=['Names','Age']
idx=['A','B','C']
#pd.DataFrame(data,index,columns)
pd.DataFrame(zip(names,age),
                index=idx,
             columns=cols)
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   22
# C  Mahesh   24

# %% [markdown]
# **step-5: create empty dataframe and update the df**

# %%
#Above one we created dataframe with values directly
# Now first we will create empty df
#then we will add the values

df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Names']
# If i run this if any column values available under names it will display
# otherwise error
# either you are creating a new column
# or you are modifying the column values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['Names']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Names'

# %%
names=['Ramesh','Suresh','Mahesh']
df['Names']=names
df['Age']=[20,22,24]
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Mahesh   24

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Mahesh']
df['Age']=[20,22,24]
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Mahesh   24

# %%
#My dataframe name is : df
df['Age']
# Out:
# 0    20
# 1    22
# 2    24
# Name: Age, dtype: int64

# %%
df['Age']=[30,32,34] #updating
df['age']=[100,200,300] #creating
df['city']=['Hyd','Blr','Chennai'] #creating
df
# Out:
#     Names  Age  age     city
# 0  Ramesh   30  100      Hyd
# 1  Suresh   32  200      Blr
# 2  Mahesh   34  300  Chennai

# %% [markdown]
# **Notes**
# - python case sensitive
# - 'Age' and 'age are considered as different
# - updated column values always should be same len dataframe
# - dont expect Null like sql if we miss any value

# %% [markdown]
# **step-6: Drop the column**
# - labels:
# - axis: 'Axis' = 0,
# - index :
# - columns:
# - inplace: 'bool' = False,

# %%
#what is our dataframe name : df
# I wnat to drop age column
# what is the age column index
# 2 or [2]??
# 2 or [2] indicates row or column
# have we mentioned to python is it a row or column : no
# python confuse
# axis

df.drop(2,axis=0) # explictly drop row
df.drop(2) #no error 2nd means 3rd rows
df.drop(2,axis=1) #exp drop column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 #what is our dataframe name : df
# ----> 2 df.drop('age')
#       3 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['age'] not found in axis"

# %%
df.drop(2)
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd
# 1  Suresh   32  200  Blr

# %%
df.drop([2])
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd
# 1  Suresh   32  200  Blr

# %%
df.drop([1,2]) #multiple means list
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd

# %%
df.drop(2,axis=0)
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd
# 1  Suresh   32  200  Blr

# %%
df.drop(2,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df.drop(2,axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[2] not found in axis'

# %%
df.drop(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df.drop(20)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[20] not found in axis'

# %%
df.drop(columns=['age'])
# Out:
#     Names  Age     city
# 0  Ramesh   30      Hyd
# 1  Suresh   32      Blr
# 2  Mahesh   34  Chennai

# %%
df.drop(index=[2])
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd
# 1  Suresh   32  200  Blr

# %%
df.columns
# Out:
# Index(['Names', 'Age', 'age', 'city'], dtype='object')

# %%
df.columns[2]
# Out:
# 'age'

# %%
df.drop('age',axis=1)
# Out:
#     Names  Age     city
# 0  Ramesh   30      Hyd
# 1  Suresh   32      Blr
# 2  Mahesh   34  Chennai

# %%
df
df.drop(2) # works
df.drop(2,axis=0) # works
df.drop(2,axis=1) # fail
df.drop('age',axis=1) # works
df.drop(labels=[2]) # works
df.drop(columns=['age']) # works
# Out:
#     Names  Age  age     city
# 0  Ramesh   30  100      Hyd
# 1  Suresh   32  200      Blr
# 2  Mahesh   34  300  Chennai

# %%
df.drop(labels=[2])
# Out:
#     Names  Age  age city
# 0  Ramesh   30  100  Hyd
# 1  Suresh   32  200  Blr

# %%
df.drop('age') #python checks in the name of 'age' row is there or not
df.drop('age',axis=1)
df.drop(columns=['age']) #thats why we mention axis or column name to let python know

# %%
df.drop(columns=['age'],
        inplace=True)

# %%
df
# Out:
#     Names  Age     city
# 0  Ramesh   30      Hyd
# 1  Suresh   32      Blr
# 2  Mahesh   34  Chennai

# %%
#Assignment-1
df.rename()
#Assignment-2
df.shape
df.size
df.columns
df.isnull()
len(df)
df.info
df.drop_duplicates
df.dtypes

# %%
# Import the packages
# created a dataframe using list
# Add a column names
# Add our own index
# created empty daraframe and we updated with data
# we learned how to modify the rows for all the column
# Drop a column and index
# axis=0 rows axis=1 columns
# inplace

# whenever we open any notebook
# 1.Import your packages cell you need to run
# 2.Data read you need to run

# %%
df=pd.DataFrame()
df['Names']=['Ramesh','suresh','satish']
df['Age']=[20,22,24]
df['city']=['hyd','blr','pune']
df
# Out:
#     Names  Age  city
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.drop(2) #2 means label is it row or column axis axis=0
df.drop(2,axis=0)
df.drop(index=2)
df.drop([1,2])
df.drop([1,2],axis=0)
df.drop(index=[1,2])

df.drop('city',axis=1)
df.drop(['Names','City'],axis=1)
df.drop(columns='city')
df.drop(columns=['Names','City'])

# %% [markdown]
# **step-7:Rename the columns and index**
#   - mapper: 'Renamer | None' = None,
#
#     - index: 'Renamer | None' = None,
#     - columns: 'Renamer | None' = None,
#     - axis: 'Axis | None' = None,
#    - copy: 'bool | None' = None,
#    - inplace: 'bool' = False,

# %% [markdown]
# **mapper means dictionary**

# %%
df.columns
dict1={'City':'city'}
df.rename(dict1) # this mapper for index or column
df.rename(dict1,axis=1,inplace=True)
df.rename(columns=dict1)
# Out:
#     Names  Age  city
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.columns=['A','B','C'] 
# Inplace also not required

# %%
df.index=['I','II','III']
df
# Out:
#       Names  Age  city
# I    Ramesh   20   hyd
# II   suresh   22   blr
# III  satish   24  pune

# %%
df.columns=['Names','Age','City']
df.index=[0,1,2]
df
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %% [markdown]
# **step-8:Append the rows**

# %% [markdown]
# - we need to use **loc**
# - df.loc[<row numbers>,<column names>]
# - df.loc[2,'city']
# - Multiple rows from multiple columns
#    - example : df.loc[[1,2],['Names','City']]
# - df.loc[Start:stop:step,<column names>]
#    - Example : df.loc[0:3,'City']

# %%
df.loc[2,'City']
# Out:
# 'pune'

# %%
df.loc[2]#2 index of all columns
df.loc[[2]] # 2nd index of all column
df.loc[[1,2]]  # 2 index -df
df.loc[0:3] - series
df.loc[:]
df.loc[2,'City']
df.loc[2,['City']]
df.loc[[1,2,],['Names','City']]
df.loc[:,'City']
df.loc[:,'City']]

# %%
type(df.loc[[2]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[2]
# Out:
# Names    satish
# Age          24
# City       pune
# Name: 2, dtype: object

# %%
df.loc[[1,2]]
# Out:
#     Names  Age  City
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.loc[0:3]
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.loc[:] #select everything
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.loc[2,'City']
# Out:
# 'pune'

# %%
df.loc[2,['City']] #dataframe
# Out:
# City    pune
# Name: 2, dtype: object

# %%
df.loc[[2],['City']]
# Out:
#    City
# 2  pune

# %%
df.loc[[1,2],['Names','City']] #df
# Out:
#     Names  City
# 1  suresh   blr
# 2  satish  pune

# %%
df.loc[:,'City']
# Out:
# 0     hyd
# 1     blr
# 2    pune
# Name: City, dtype: object

# %%
df.loc[:,['City']] #df
# Out:
#    City
# 0   hyd
# 1   blr
# 2  pune

# %%
list(range(0,3))
# Out:
# [0, 1, 2]

# %% [markdown]
# **iloc**

# %%
df.loc[<rows>,<column>]
df.iloc[<rows>,'City']
df.iloc[<rows>,2]

# %%
df.loc[2]#2 index of all columns
df.loc[[2]] # 2nd index of all column
df.loc[[1,2]]  # 2 index -df
df.loc[0:3] - series
df.loc[:]
df.loc[2,'City']
df.loc[2,['City']]
df.loc[[1,2,],['Names','City']]
df.loc[:,'City']
df.loc[:,'City']]

# %%
df.iloc[2]
# Out:
# Names    satish
# Age          24
# City       pune
# Name: 2, dtype: object

# %%
df.iloc[[2]]
# Out:
#     Names  Age  City
# 2  satish   24  pune

# %%
df.iloc[[1,2]]
# Out:
#     Names  Age  City
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.iloc[0:3]
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.iloc[:]
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
df.iloc[2,2]
# Out:
# 'pune'

# %%
df.iloc[2,[2]]
# Out:
# City    pune
# Name: 2, dtype: object

# %%
df.iloc[[2],[2]]
# Out:
#    City
# 2  pune

# %%
df.iloc[[1,2],[0,2]]
# Out:
#     Names  City
# 1  suresh   blr
# 2  satish  pune

# %%
df.iloc[:,1]
# Out:
# 0    20
# 1    22
# 2    24
# Name: Age, dtype: int64

# %%
df.iloc[:,[2]]
# Out:
#    City
# 0   hyd
# 1   blr
# 2  pune

# %% [markdown]
# - .loc → “Find by header name / row name”
#
# - .iloc → “Find by row number / column number”
#
# - .loc name, iloc number
#
# - comapred to both loc is better remembersing the name is easy

# %%
df.iloc[:,[2]]
df.iloc[0:3,[2]] #0:3 [0,1,2]
df.iloc

# %% [markdown]
# **step-9: save the dataframe**
# - where i want to save
# - - on what name i want to save
# - on what extension i want to save .csv,.xlsx

# %%
path1=r'C:\Naresh IT\employees.csv' #absoulte path
path2=r'employees.csv' # saved in current working directory
path3=r'C:\Naresh IT\employees.xlsx'
path4=r'employees.xlsx'

df.to_csv(path1)
df.to_csv(path2)
df.to_excel(path3)
df.to_excel(path4)

# %% [markdown]
# **step-10 : read the dataframe**

# %%
pd.read_csv(path1)
# Out:
#    Unnamed: 0   Names  Age  City
# 0           0  Ramesh   20   hyd
# 1           1  suresh   22   blr
# 2           2  satish   24  pune

# %%
pd.read_excel(path3)
# Out:
#    Unnamed: 0   Names  Age  City
# 0           0  Ramesh   20   hyd
# 1           1  suresh   22   blr
# 2           2  satish   24  pune

# %%
path1=r'C:\Naresh IT\employees.csv' #absoulte path
path2=r'employees.csv' # saved in current working directory
path3=r'C:\Naresh IT\employees.xlsx'
path4=r'employees.xlsx'

df.to_csv(path1,index=False)
df.to_csv(path2,index=False)
df.to_excel(path3,index=False)
df.to_excel(path4,index=False)

# %%
pd.read_csv(path1)
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune

# %%
pd.read_excel(path3)
# Out:
#     Names  Age  City
# 0  Ramesh   20   hyd
# 1  suresh   22   blr
# 2  satish   24  pune
